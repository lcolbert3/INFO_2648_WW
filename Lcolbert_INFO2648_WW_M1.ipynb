# %%
#Louis Colbert III
#M1 Assignment

# %% [markdown]
# # Sections are below under the "Section Headers"

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Datasets/datasets/data/housing.csv')

# %%
df.head(3)
# Out:
#   Neighborhood Building.Classification  Total.Units  Year.Built  Gross.SqFt  \
# 0    FINANCIAL          R9-CONDOMINIUM           42      1920.0       36500
# 1    FINANCIAL          R4-CONDOMINIUM           78      1985.0      126420
# 2    FINANCIAL          RR-CONDOMINIUM          500         NaN      554174
#
#    Estimated.Gross.Income  Gross.Income.per.SqFt  Estimated.Expense  \
# 0                 1332615                  36.51             342005
# 1                 6633257                  52.47            1762295
# 2                17310000                  31.24            3543000
#
#    Expense.per.SqFt  Net.Operating.Income  Full.Market.Value  \
# 0              9.37                990610            7300000
# 1             13.94               4870962           30690000
# 2              6.39              13767000           90970000
#
#    Market.Value.per.SqFt       Boro
# 0                 200.00  Manhattan
# 1                 242.76  Manhattan
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.shape
# Out:
# (2626, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2626 entries, 0 to 2625
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Neighborhood             2626 non-null   str
#  1   Building.Classification  2626 non-null   str
#  2   Total.Units              2626 non-null   int64
#  3   Year.Built               2530 non-null   float64
#  4   Gross.SqFt               2626 non-null   int64
#  5   Estimated.Gross.Income   2626 non-null   int64
#  6   Gross.Income.per.SqFt    2626 non-null   float64
#  7   Estimated.Expense        2626 non-null   int64
#  8   Expense.per.SqFt         2626 non-null   float64
#  9   Net.Operating.Income     2626 non-null   int64
#  10  Full.Market.Value        2626 non-null   int64
#  11  Market.Value.per.SqFt    2626 non-null   float64
#  12  Boro                     2626 non-null   str
# dtypes: float64(4), int64(6), str(3)
# memory usage: 266.8 KB

# %%
df = df[['Boro', 'Building.Classification', 'Year.Built', 'Gross.SqFt', 'Full.Market.Value']]

# %%
df.head()
# Out:
#         Boro Building.Classification  Year.Built  Gross.SqFt  \
# 0  Manhattan          R9-CONDOMINIUM      1920.0       36500
# 1  Manhattan          R4-CONDOMINIUM      1985.0      126420
# 2  Manhattan          RR-CONDOMINIUM         NaN      554174
# 3  Manhattan          R4-CONDOMINIUM      1930.0      249076
# 4  Manhattan          R4-CONDOMINIUM      1985.0      219495
#
#    Full.Market.Value
# 0            7300000
# 1           30690000
# 2           90970000
# 3           67556006
# 4           54320996

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2626 entries, 0 to 2625
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Boro                     2626 non-null   str
#  1   Building.Classification  2626 non-null   str
#  2   Year.Built               2530 non-null   float64
#  3   Gross.SqFt               2626 non-null   int64
#  4   Full.Market.Value        2626 non-null   int64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 102.7 KB

# %%
df.Boro
# Out:
# 0           Manhattan
# 1           Manhattan
# 2           Manhattan
# 3           Manhattan
# 4           Manhattan
#             ...
# 2621    Staten Island
# 2622    Staten Island
# 2623    Staten Island
# 2624    Staten Island
# 2625    Staten Island
# Name: Boro, Length: 2626, dtype: str

# %%
df.columns
# Out:
# Index(['Boro', 'Building.Classification', 'Year.Built', 'Gross.SqFt',
#        'Full.Market.Value'],
#       dtype='str')

# %%
df.iloc[0]
# Out:
# Boro                            Manhattan
# Building.Classification    R9-CONDOMINIUM
# Year.Built                         1920.0
# Gross.SqFt                          36500
# Full.Market.Value                 7300000
# Name: 0, dtype: object

# %%
df_subset = df.iloc[2521:2541]

# %% [markdown]
# ## Section 1

# %%
# Since python starts at 0 for the indexing using 2521 to 2541 as those are the true rows.

# %%
print(df_subset)
# Out:
#         Boro Building.Classification  Year.Built  Gross.SqFt  \
# 2521  Queens          R4-CONDOMINIUM      2006.0      111775
# 2522  Queens          R4-CONDOMINIUM      2005.0       93315
# 2523  Queens          R4-CONDOMINIUM      2005.0       82862
# 2524  Queens          R2-CONDOMINIUM      2005.0       27560
# 2525  Queens          R4-CONDOMINIUM      2009.0       48680
# 2526  Queens          R2-CONDOMINIUM      2007.0       98222
# 2527  Queens          R2-CONDOMINIUM      2006.0       53200
# 2528  Queens          R4-CONDOMINIUM      2005.0       74400
# 2529  Queens          R4-CONDOMINIUM      2005.0       41713
# 2530  Queens          R9-CONDOMINIUM      1986.0       82600
# 2531   Bronx          R2-CONDOMINIUM      1904.0       21092
# 2532   Bronx          R4-CONDOMINIUM      2006.0       72000
# 2533   Bronx          R4-CONDOMINIUM      2007.0      150121
# 2534   Bronx          R4-CONDOMINIUM      2007.0       63872
# ...

# %% [markdown]
# ## Section 2

# %%
df_subset.groupby('Boro')['Full.Market.Value'].mean()
# Out:
# Boro
# Bronx     3050799.4
# Queens    7478304.2
# Name: Full.Market.Value, dtype: float64
