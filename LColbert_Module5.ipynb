# %% [markdown]
# ## Class: 26SS INFO 2648 WW

# %% [markdown]
# ## Name: Louis Colbert III

# %% [markdown]
# Program
#
# Write a program using the attached datasets above by doing the following:
#
# 1. Provide a count of all the missing values for columns "LotFrontage" and "Alley".
# 2. Use interpolate to fill missing values for rows 7 - 17 and columns 0 - 8.
# 3. Display a second subset for data that fills missing values with "none" for rows 7 - 17 and columns 0 - 8.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
# gathered the missing lotfrontage data count
missing_frontage = df['LotFrontage'].isna().sum()

# %%
missing_frontage
# Out:
# np.int64(259)

# %%
# got the missing alley data count
missing_alley = df['Alley'].isna().sum()

# %%
missing_alley
# Out:
# np.int64(1369)

# %%
#made a copy of the data to be used to not ruin the base data.
df_interpolated = df.copy()

# %%
# getting the subset of the data
subset_of_interpolate = df_interpolated.iloc[7:18, 0:9]

# %%
#checking the data
subset_of_interpolate
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 17  18          90       RL         72.0    10791   Pave   NaN      Reg
#
#    LandContour
# 7          Lvl
# 8          Lvl
# 9          Lvl
# 10         Lvl
# 11         Lvl
# ...

# %%
subset_of_interpolate.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11 entries, 7 to 17
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           11 non-null     int64
#  1   MSSubClass   11 non-null     int64
#  2   MSZoning     11 non-null     str
#  3   LotFrontage  7 non-null      float64
#  4   LotArea      11 non-null     int64
#  5   Street       11 non-null     str
#  6   Alley        0 non-null      str
#  7   LotShape     11 non-null     str
#  8   LandContour  11 non-null     str
# dtypes: float64(1), int64(3), str(5)
# memory usage: 924.0 bytes

# %%
#converting the data to a number to run interpolate
subset_of_interpolate['Alley'] = pd.to_numeric(subset_of_interpolate['Alley'])

# %%
subset_of_interpolate.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11 entries, 7 to 17
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           11 non-null     int64
#  1   MSSubClass   11 non-null     int64
#  2   MSZoning     11 non-null     str
#  3   LotFrontage  7 non-null      float64
#  4   LotArea      11 non-null     int64
#  5   Street       11 non-null     str
#  6   Alley        0 non-null      float64
#  7   LotShape     11 non-null     str
#  8   LandContour  11 non-null     str
# dtypes: float64(2), int64(3), str(4)
# memory usage: 924.0 bytes

# %%
subset_of_interpolate['LotFrontage'] =  subset_of_interpolate['LotFrontage'].interpolate(method="linear",limit_direction="both")

# %%
subset_of_interpolate.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11 entries, 7 to 17
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           11 non-null     int64
#  1   MSSubClass   11 non-null     int64
#  2   MSZoning     11 non-null     str
#  3   LotFrontage  11 non-null     float64
#  4   LotArea      11 non-null     int64
#  5   Street       11 non-null     str
#  6   Alley        0 non-null      float64
#  7   LotShape     11 non-null     str
#  8   LandContour  11 non-null     str
# dtypes: float64(2), int64(3), str(4)
# memory usage: 924.0 bytes

# %%
subset_of_interpolate['Alley'] = subset_of_interpolate['Alley'].interpolate(method= "linear", limit_direction="both")

# %% [markdown]
# ### 2. Use interpolate to fill missing values for rows 7 - 17 and columns 0 - 8.

# %%
subset_of_interpolate
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 7    8          60       RL         51.0    10382   Pave    NaN      IR1
# 8    9          50       RM         51.0     6120   Pave    NaN      Reg
# 9   10         190       RL         50.0     7420   Pave    NaN      Reg
# 10  11          20       RL         70.0    11200   Pave    NaN      Reg
# 11  12          60       RL         85.0    11924   Pave    NaN      IR1
# 12  13          20       RL         88.0    12968   Pave    NaN      IR2
# 13  14          20       RL         91.0    10652   Pave    NaN      IR1
# 14  15          20       RL         71.0    10920   Pave    NaN      IR1
# 15  16          45       RM         51.0     6120   Pave    NaN      Reg
# 16  17          20       RL         61.5    11241   Pave    NaN      IR1
# 17  18          90       RL         72.0    10791   Pave    NaN      Reg
#
#    LandContour
# 7          Lvl
# 8          Lvl
# 9          Lvl
# 10         Lvl
# ...

# %% [markdown]
# ### 3. Display a second subset for data that fills missing values with "none" for rows 7 - 17 and columns 0 - 8.

# %%
# Fill missing values with the string "none"
subset_of_interpolate = subset_none.fillna("none")

# %%
subset_of_interpolate
# Out:
#     Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 7    8          60       RL        none    10382   Pave  none      IR1
# 8    9          50       RM        51.0     6120   Pave  none      Reg
# 9   10         190       RL        50.0     7420   Pave  none      Reg
# 10  11          20       RL        70.0    11200   Pave  none      Reg
# 11  12          60       RL        85.0    11924   Pave  none      IR1
# 12  13          20       RL        none    12968   Pave  none      IR2
# 13  14          20       RL        91.0    10652   Pave  none      IR1
# 14  15          20       RL        none    10920   Pave  none      IR1
# 15  16          45       RM        51.0     6120   Pave  none      Reg
# 16  17          20       RL        none    11241   Pave  none      IR1
# 17  18          90       RL        72.0    10791   Pave  none      Reg
#
#    LandContour
# 7          Lvl
# 8          Lvl
# 9          Lvl
# 10         Lvl
# 11         Lvl
# 12         Lvl
# ...
